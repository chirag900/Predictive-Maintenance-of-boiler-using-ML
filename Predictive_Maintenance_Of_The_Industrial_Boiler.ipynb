# %% [markdown]
# ##  PdM Summary :
#
# #### Motivation :
#
# Currently, the industry is going through what experts have called “The Fourth Industrial Revolution”, also called Industry 4.0. This fact is strongly associated with the integration between physical and digital systems of production environments. The integration of these environments allows the collection of a large amount of data that is collected by different equipment, located in different sectors of the factories. In addition, new technologies from Industry 4.0 integrate people, machines and products, enabling faster and more targeted exchange of information.
#
# The amount of data extracted from production processes has increased exponentially due to the proliferation of sensing technologies. When processed and analyzed, data can bring out valuable information and knowledge from manufacturing process, production system and industrial working equipment. In industries, equipment maintenance is an important key, and affects the operation time of equipment and its efficiency. Thus, equipment faults need to be identified and solved, avoiding shutdown in the production processes.
#
# #### Run-to-Failure (R2F) or Corrective maintenance
# This happens only when an equipment stops working. This is the simplest maintenance strategy, since it is necessary both the stop on the production and the repair of the parts to be replaced, adding a direct cost to the process.
#
# #### Preventive Maintenance (PVM):
# Time-based maintenance or Scheduled maintenance is a maintenance technique performed periodically with a planned schedule in time or process iterations to anticipate process/ equipment failures. It is generally an effective approach to avoid failures. However, unnecessary corrective actions are taken, leading to an increase in the operating costs.
#
# #### Predictive Maintenance (PdM) :
# This uses predictive tools to determine when maintenance actions are necessary. It is based on continuous monitoring of a machine or a process integrity, allowing maintenance to be performed only when it is needed. Moreover, it allows the early detection of failures thanks to predictive tools based on historical data (e.g. machine learning techniques), integrity factors(e.g. visual aspects, wear, coloration different from original, among others), statistical inference methods and engineering approaches.
#
# #### Key Advantages of PdM:
#
# a. maximizing time of use of the equipment
#
# b. delaying/reducing maintenance activities
#
# c. reducing material and labor costs.
#
# #### 2. Problem Definition and about the Dataset:
# i. Data sets consists of multiple multivariate time series. Each data set is further divided into training and test subsets. Each time series is from a different boiler i.e., the data can be considered to be from a fleet of boilers of the same type.
#
# ii. Each boiler (Boiler tube) starts with different degrees of initial wear and manufacturing variation which is unknown to the user. This wear and variation is considered normal, i.e., it is not considered a fault condition. There are three operational settings that have a substantial effect on boiler performance. These settings are also included in the data.
#
# iii. The boiler is operating normally at the start of each time series, and develops a fault at some point during the series. In the training set, the fault grows in magnitude until system failure.
#
# #### Task 1 : In the test set, the time series ends some time prior to system failure. The objective of this project is to predict the number of remaining operational cycles before failure in the 	test set, i.e., the number of operational cycles after the last cycle that the boiler will continue 	to operate. Also provided a vector of true Remaining Useful Life (RUL) values for the test 	data.
#
# #### Task 2 : Predict if a boiler will fail within certain time frame (e.g. days) with given data.
#
# #### Sample Data Features:
#
# ![1.png](attachment:1.png)
#
# #### 3. Find the Target_RUL :
# i. Find the last cycle per boiler id (ie, maximum cycle )
#
# ii. Then group by th boiler_id and find the maximum RUL for every boiler.
#
# iii. Find the target_RUL for each row ( Target_RUL = Max_Cycle_RUL – RUL), which is the remaining useful lifetime of that boiler for the given features.
#
#
# #### 4. Data Cleaning and EDA :
# #### With Respect To Regression:
#
# Plot of RUL vs All sensor readings indidually.
#
# i. The Operational setting1, setting2 and CO leakage readings vary sinosoidally with respect to “RUL”.
#
# ii. Operational setting3 , Water_flow_rate readings remain constant even if the RUL changing.
#
# iii. As Temperature, Pressure readings increasing, then Target_RUL is decreasing and there is sudden drop in the curve at some value of temperature.
#
# iv. As fuel flow rate and velocity of the gas increases, RUL also increases upto certain values of Velocity and fuel flow rate, then values suddenly decrease. (The point at which sudden decrease in the readings and the value at that point could be the threshold value of Velocity and fuel flow rate).
#
# v. Plot the variation of Operational setting1 and setting 2 with respect to all the features. Using this we can find the range of variation of the Temperature, Pressure, Velocity, fuelflow rate, water flow rate with given Operational setting1 and setting2.
#
#
# #### 5. Finding the Feature importance using “Random Forest” with  :
# ##### depth of the Tree = 15 and	Number of Trees = 200
#
# #### 6. Model Training and Evaluation (Regresion) :
# #### A. RandomForest Regression:
# i. Split the data into train and test dataset.
#
# ii. importing RandomForest Regressor and perform 5 fold crossvalidation.
#
# iii. Find the best hyper parameters (number of trees and depth of the tree) using GridsearchCV
#
# iv. Fit the model with the best hyperparameters and train.
#
# v. Find the value of metrics like “Root Mean Square Error”, Mean Absolute Error and  r2_score.
#
# ![2.png](attachment:2.png)
#
# #### B. Support Vector Machine (Regression):
# i. simillarly import the libraries find the best hyper parameters using GridSearchCV : hyper parameters are : Regularization parameter (C) and epsilon is the margin (Distance from the hyperplane on either side).
#
# ii. Fit the SVR and compute the RMSE, MAE and r2_Score.
#
# ![3.png](attachment:3.png)
#
# #### C. Gradient Boosting :
# i. import the GradientBoosting Regressor and create an object of the model.
#
# ii. Find the best hyperparameters like alpha (regularization parameter) , number of estimators , learning rate and maximum depth using Gridsearch CV.
#
# iii. Fit the model with the best hyperparameters and estimate the MSE, MAE and r2_Score.
#
# ![4.png](attachment:4.png)
#
# ### CONCLUSION :
#
# From the analysis we can conclude that Gradient Boosting is the best model which is more accurate.

# %% [markdown]
# ## Classification Task:
# #### With Respect To Classification:
# i. The dataset is highly imbalanced, ie, more number of non-failure points than the failure points.
#
# ii. Train Logistic Regression with SGDClassifier with Balanced weights. The hyper parameters as alpha (Regularization parameter) and find the least log loss value which is also a hyperparameter.
#
# iii. Predict if a boiler will fail within certain time frame ie, predict the class label (Binary classification) of the boiler.
#
# iv. Simillarly Train RandomForest Classifier model using the train data
#
# v. Determine the best hyperparameters (number_of_Trees and depth_Of_the_Tree) using the GridSearchCV.
#
# vi. Predict on the test data using this RandomForestClassifier.
#
# ![5.png](attachment:5.png)
#
# #### CONCLUSION :
# RandomForest classifier is selected as it gives the least error and with the best accuracy.
#
#
# ### Business Impact :
# i. PdM can bring huge value for business since PdM helps to reduce the downtime of the equipment.
#
# ii. Helps to avoid inconvience caused to the end users or customers.
#
# iii. Complete use of the available resources.
